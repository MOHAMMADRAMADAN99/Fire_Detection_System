# %%
# !pip install ultralytics
import ultralytics
from ultralytics import  YOLO
from google.colab.patches import cv2_imshow

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.9/78.2 GB disk)

# %%
import os
from IPython.display import  display,Image

# %%
# !curl -L "https://universe.roboflow.com/ds/gpBi5Ha1fb?key=UpDzLXi0wn"  >  roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# %%
# !yolo task=detect \
mode=train \
model=yolov8m.pt \
data=data.yaml \
epochs=30 \
imgsz=640
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model =  YOLO('/content/runs/detect/train2/weights/best.pt')

# %%
image_path = 'fire.3.png'
model.predict(image_path, save=True, imgsz=320, conf=0.1)


# Display the image
img_path = '/content/runs/detect/predict/'+image_path
display(Image(filename=img_path))
# Out:
# image 1/1 /content/fire.3.png: 192x320 3 2s, 16.3ms
# Speed: 1.5ms preprocess, 16.3ms inference, 1.9ms postprocess per image at shape (1, 3, 192, 320)
# Results saved to runs/detect/predict

# %%
model.predict('../fire.5.png', save=True, imgsz=320, conf=0.3)

# %%
model.predict('/content/valid/images/fire1_mp4-23_jpg.rf.b850daa870400ff73c1f4b1f3313f03a.jpg', save=True, imgsz=320, conf=0.3)
